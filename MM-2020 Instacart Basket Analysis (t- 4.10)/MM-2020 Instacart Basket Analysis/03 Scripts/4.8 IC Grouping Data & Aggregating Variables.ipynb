# %% [markdown]
# # Task 4.8 - Grouping Data & Aggregating Variables

# %% [markdown]
# ## This script includes the following points:

# %% [markdown]
# ### 01. Importing Libraries

# %% [markdown]
# ### 02. Importing Data

# %% [markdown]
# ### 03. Calculate Mean of Order Number

# %% [markdown]
# ### 04. Create Loyalty Flag for Exisiting Customers

# %% [markdown]
# ### 05. Spending Habits of Loyalty Groups

# %% [markdown]
# ### 06. Create a spending flag for each user based on the average price across all their orders

# %% [markdown]
#  ### 07. Determine Order Frequency of Each Use

# %% [markdown]
# # Task Step 1. Importing Libraries

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Task Step 2. Importing Data

# %%
# Importing dataframe
path = r'C:\Users\Sanket\Documents\MM-2020 Instacart Basket Analysis'

# %%
# Import data set
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_derived.pkl'))

# %%
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 19)

# %%
df.head(10)
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
# 5           1  Chocolate Sandwich Cookies        61             19     5.8
# 6           1  Chocolate Sandwich Cookies        61             19     5.8
# 7           1  Chocolate Sandwich Cookies        61             19     5.8
# 8           1  Chocolate Sandwich Cookies        61             19     5.8
# 9           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   3139998      138    prior            28                   6
# 1   1977647      138    prior            30                   6
# 2    389851      709    prior             2                   0
# 3    652770      764    prior             1                   3
# 4   1813452      764    prior             3                   4
# 5   1701441      777    prior            16                   1
# 6   1871483      825    prior             3                   2
# 7   1290456      910    prior            12                   3
# 8    369558     1052    prior            10                   1
# 9    589712     1052    prior            15                   1
#
#    order_hour_of_day  days_since_prior_order  add_to_cart_order  reordered  \
# 0                 11                     3.0                  5          0
# 1                 17                    20.0                  1          1
# 2                 21                     6.0                 20          0
# 3                 13                     NaN                 10          0
# 4                 17                     9.0                 11          1
# 5                  7                    26.0                  7          0
# 6                 14                    30.0                  2          0
# 7                 10                    30.0                  1          0
# 8                 20                    19.0                  1          0
# 9                 12                    15.0                  2          1
#
#   _merge     price_range_loc     busiest_day    busiest_days  \
# 0   both  High-range product  Regularly busy  Regularly busy
# 1   both  High-range product  Regularly busy  Regularly busy
# 2   both  High-range product     Busiest day    Busiest days
# 3   both  High-range product  Regularly busy    Slowest days
# 4   both  High-range product      Least busy    Slowest days
# 5   both  High-range product  Regularly busy    Busiest days
# 6   both  High-range product  Regularly busy  Regularly busy
# 7   both  High-range product  Regularly busy    Slowest days
# 8   both  High-range product  Regularly busy    Busiest days
# 9   both  High-range product  Regularly busy    Busiest days
#
#   busiest_period_of_day
# 0           Most orders
# 1        Average orders
# 2        Average orders
# 3           Most orders
# 4        Average orders
# 5        Average orders
# 6           Most orders
# 7           Most orders
# 8        Average orders
# 9           Most orders

# %%
df.groupby('product_name')

# %% [markdown]
# # Task Step 3- Calculate Mean of Order Number

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.577493
# 2                17.320781
# 3                16.084944
# 4                17.530458
# 5                14.763075
# 6                16.658449
# 7                17.031590
# 8                15.076662
# 9                15.447580
# 10               18.681852
# 11               15.447411
# 12               14.327957
# 13               16.548642
# 14               16.960241
# 15               16.121948
# 16               17.803851
# 17               15.593633
# 18               19.674252
# 19               16.899756
# 20               16.255442
# 21               25.535479

# %% [markdown]
# # Task Step 4- Create Loyalty Flag for Exisiting Customers

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\Sanket\AppData\Local\Temp\ipykernel_3864\1681540670.py:1: FutureWarning: The provided callable <function max at 0x000001BAC9FAF9C0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# View updated data frame
ords_prods_merge.head(15)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# 11           1  Chocolate Sandwich Cookies        61             19     5.8
# 12           1  Chocolate Sandwich Cookies        61             19     5.8
# 13           1  Chocolate Sandwich Cookies        61             19     5.8
# 14           1  Chocolate Sandwich Cookies        61             19     5.8
#
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    3139998      138    prior            28                   6
# 1    1977647      138    prior            30                   6
# 2     389851      709    prior             2                   0
# 3     652770      764    prior             1                   3
# 4    1813452      764    prior             3                   4
# 5    1701441      777    prior            16                   1
# 6    1871483      825    prior             3                   2
# 7    1290456      910    prior            12                   3
# 8     369558     1052    prior            10                   1
# 9     589712     1052    prior            15                   1
# 10   1798115     1379    prior             1                   5
# 11    497193     1480    prior            36                   3
# 12   1727826     1480    prior            38                   4
# 13   2694698     1480    prior            39                   2
# 14   3171753     1494    prior             6                   3
#
#     order_hour_of_day  days_since_prior_order  add_to_cart_order  reordered  \
# 0                  11                     3.0                  5          0
# 1                  17                    20.0                  1          1
# 2                  21                     6.0                 20          0
# 3                  13                     NaN                 10          0
# 4                  17                     9.0                 11          1
# 5                   7                    26.0                  7          0
# 6                  14                    30.0                  2          0
# 7                  10                    30.0                  1          0
# 8                  20                    19.0                  1          0
# 9                  12                    15.0                  2          1
# 10                 11                     NaN                  1          0
# 11                 13                     7.0                  1          0
# 12                 13                     7.0                  3          1
# 13                 12                    12.0                  4          1
# 14                 10                     2.0                  8          0
#
#    _merge     price_range_loc     busiest_day    busiest_days  \
# 0    both  High-range product  Regularly busy  Regularly busy
# 1    both  High-range product  Regularly busy  Regularly busy
# 2    both  High-range product     Busiest day    Busiest days
# 3    both  High-range product  Regularly busy    Slowest days
# 4    both  High-range product      Least busy    Slowest days
# 5    both  High-range product  Regularly busy    Busiest days
# 6    both  High-range product  Regularly busy  Regularly busy
# 7    both  High-range product  Regularly busy    Slowest days
# 8    both  High-range product  Regularly busy    Busiest days
# 9    both  High-range product  Regularly busy    Busiest days
# 10   both  High-range product  Regularly busy  Regularly busy
# 11   both  High-range product  Regularly busy    Slowest days
# 12   both  High-range product      Least busy    Slowest days
# 13   both  High-range product  Regularly busy  Regularly busy
# 14   both  High-range product  Regularly busy    Slowest days
#
#    busiest_period_of_day  max_order
# 0            Most orders         32
# 1         Average orders         32
# 2         Average orders          5
# 3            Most orders          3
# 4         Average orders          3
# 5         Average orders         26
# 6            Most orders          9
# 7            Most orders         12
# 8         Average orders         20
# 9            Most orders         20
# 10           Most orders         10
# 11           Most orders         43
# 12           Most orders         43
# 13           Most orders         43
# 14           Most orders         13

# %%
# Use loc function to make loyalty flag column with given criteria
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Check frequency of values in new loyalty flag column
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
# View updated data frame
ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  orders_day_of_week  ...  \
# 0   3139998      138    prior            28                   6  ...
# 1   1977647      138    prior            30                   6  ...
# 2    389851      709    prior             2                   0  ...
# 3    652770      764    prior             1                   3  ...
# 4   1813452      764    prior             3                   4  ...
#
#    days_since_prior_order  add_to_cart_order  reordered  _merge  \
# 0                     3.0                  5          0    both
# 1                    20.0                  1          1    both
# 2                     6.0                 20          0    both
# 3                     NaN                 10          0    both
# 4                     9.0                 11          1    both
#
#       price_range_loc     busiest_day    busiest_days busiest_period_of_day  \
# 0  High-range product  Regularly busy  Regularly busy           Most orders
# 1  High-range product  Regularly busy  Regularly busy        Average orders
# 2  High-range product     Busiest day    Busiest days        Average orders
# 3  High-range product  Regularly busy    Slowest days           Most orders
# 4  High-range product      Least busy    Slowest days        Average orders
#
#   max_order      loyalty_flag
# 0        32  Regular customer
# 1        32  Regular customer
# 2         5      New customer
# 3         3      New customer
# 4         3      New customer
#
# [5 rows x 21 columns]

# %% [markdown]
# # Task Step 5-Spending Habits of Loyalty Groups

# %%
# Use groupby and agg() to determine basic statisitcs of spending habits by loyalty group
ords_prods_merge.groupby('loyalty_flag').agg({'prices' : ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# The average price of a product purchased by a new customer is about $3 more than that of a loyal customer.

# %% [markdown]
# # Task Step 6- Create a spending flag for each user based on the average price across all their orders

# %%
# Use transform() to determine the mean price of products purchased by each user
ords_prods_merge['mean_product_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# C:\Users\Sanket\AppData\Local\Temp\ipykernel_3864\4025210921.py:2: FutureWarning: The provided callable <function mean at 0x000001BAC9FB8400> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['mean_product_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# View relevant columns 
ords_prods_merge[['user_id', 'mean_product_price']].head(20)
# Out:
#     user_id  mean_product_price
# 0       138            6.935811
# 1       138            6.935811
# 2       709            7.930208
# 3       764            4.972414
# 4       764            4.972414
# 5       777            6.935398
# 6       825            5.957576
# 7       910            6.680000
# 8      1052            7.162500
# 9      1052            7.162500
# 10     1379            5.813636
# 11     1480            5.081633
# 12     1480            5.081633
# 13     1480            5.081633
# 14     1494            6.803797
# 15     1494            6.803797
# 16     1494            6.803797
# 17     1540            6.607122
# 18     1540            6.607122
# 19     1540            6.607122

# %%
# Create spending_flag column with given criteria using loc() function
ords_prods_merge.loc[ords_prods_merge['mean_product_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
ords_prods_merge.loc[ords_prods_merge['mean_product_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
#Check frequency of new spending_flag column
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low spender     31770614
# High spender      634245
# Name: count, dtype: int64

# %%
# View relevant columns of updated data frame
ords_prods_merge[['user_id', 'mean_product_price', 'spending_flag']].head(20)
# Out:
#     user_id  mean_product_price spending_flag
# 0       138            6.935811   Low spender
# 1       138            6.935811   Low spender
# 2       709            7.930208   Low spender
# 3       764            4.972414   Low spender
# 4       764            4.972414   Low spender
# 5       777            6.935398   Low spender
# 6       825            5.957576   Low spender
# 7       910            6.680000   Low spender
# 8      1052            7.162500   Low spender
# 9      1052            7.162500   Low spender
# 10     1379            5.813636   Low spender
# 11     1480            5.081633   Low spender
# 12     1480            5.081633   Low spender
# 13     1480            5.081633   Low spender
# 14     1494            6.803797   Low spender
# 15     1494            6.803797   Low spender
# 16     1494            6.803797   Low spender
# 17     1540            6.607122   Low spender
# 18     1540            6.607122   Low spender
# 19     1540            6.607122   Low spender

# %% [markdown]
# # Task Step 7- Determine Order Frequency of Each Use

# %%
# Use groupby and transform to determine median number of days between orders for each user
ords_prods_merge['median_days_between_orders'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)
# Out:
# C:\Users\Sanket\AppData\Local\Temp\ipykernel_3864\2923105074.py:2: FutureWarning: The provided callable <function median at 0x000001BACA1E4720> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   ords_prods_merge['median_days_between_orders'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# View relevant columns of updated dataframe
ords_prods_merge[['user_id', 'days_since_prior_order', 'median_days_between_orders']].head(20)
# Out:
#     user_id  days_since_prior_order  median_days_between_orders
# 0       138                     3.0                         8.0
# 1       138                    20.0                         8.0
# 2       709                     6.0                         8.0
# 3       764                     NaN                         9.0
# 4       764                     9.0                         9.0
# 5       777                    26.0                        11.0
# 6       825                    30.0                        20.0
# 7       910                    30.0                         6.0
# 8      1052                    19.0                        10.0
# 9      1052                    15.0                        10.0
# 10     1379                     NaN                        20.0
# 11     1480                     7.0                         7.0
# 12     1480                     7.0                         7.0
# 13     1480                    12.0                         7.0
# 14     1494                     2.0                         7.0
# 15     1494                     6.0                         7.0
# 16     1494                    10.0                         7.0
# 17     1540                     7.0                         7.0
# 18     1540                     6.0                         7.0
# 19     1540                    14.0                         7.0

# %%
ords_prods_merge.loc[ords_prods_merge['median_days_between_orders'] <= 10, 'order_frequency'] = 'Frequent customer'

# %%
# Check value counts of new order_frequency column
ords_prods_merge['order_frequency'].value_counts(dropna = False)
# Out:
# order_frequency
# Frequent customer    21559853
# nan                  10845006
# Name: count, dtype: int64

# %% [markdown]
# There might be rows that were not labeled. This could be because some users have only ever made one order.

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] >100, 'prices'] = np.nan

# %%
# View relevant columns of updated data frame
ords_prods_merge[['user_id', 'days_since_prior_order', 'median_days_between_orders', 'order_frequency']].head(25)
# Out:
#     user_id  days_since_prior_order  median_days_between_orders  \
# 0       138                     3.0                         8.0
# 1       138                    20.0                         8.0
# 2       709                     6.0                         8.0
# 3       764                     NaN                         9.0
# 4       764                     9.0                         9.0
# 5       777                    26.0                        11.0
# 6       825                    30.0                        20.0
# 7       910                    30.0                         6.0
# 8      1052                    19.0                        10.0
# 9      1052                    15.0                        10.0
# 10     1379                     NaN                        20.0
# 11     1480                     7.0                         7.0
# 12     1480                     7.0                         7.0
# 13     1480                    12.0                         7.0
# 14     1494                     2.0                         7.0
# 15     1494                     6.0                         7.0
# 16     1494                    10.0                         7.0
# 17     1540                     7.0                         7.0
# 18     1540                     6.0                         7.0
# 19     1540                    14.0                         7.0
# 20     1540                     8.0                         7.0
# 21     1540                     6.0                         7.0
# 22     1540                    28.0                         7.0
# 23     1540                     7.0                         7.0
# 24     1540                     7.0                         7.0
#
#       order_frequency
# 0   Frequent customer
# 1   Frequent customer
# 2   Frequent customer
# 3   Frequent customer
# 4   Frequent customer
# 5                 nan
# 6                 nan
# 7   Frequent customer
# 8   Frequent customer
# 9   Frequent customer
# 10                nan
# 11  Frequent customer
# 12  Frequent customer
# 13  Frequent customer
# 14  Frequent customer
# 15  Frequent customer
# 16  Frequent customer
# 17  Frequent customer
# 18  Frequent customer
# 19  Frequent customer
# 20  Frequent customer
# 21  Frequent customer
# 22  Frequent customer
# 23  Frequent customer
# 24  Frequent customer

# %% [markdown]
# # Task Step 7- Exporting Data

# %%
# Export derived data frame as pickle file
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_grouped.pkl'))
